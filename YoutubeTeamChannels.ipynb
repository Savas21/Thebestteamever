# %%
#Dependencies
import json
import requests
import numpy as np
import pandas as pd
from youtube_api import API_Key
import itertools
import datetime as dt
import time
# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#List of channels that needs to query channel information
teams_Youtube_Channels=["fnaticTV","G2 Esports", "Splyce", "Team Vitality", "ROCCAT",
                       "Misfits Gaming", "H2K", "FC Schalke 04 Esports", "Giants Gaming","Unicorns Of Love",
                       "100 Thieves", "Clutch Gaming", "FlyQuest Sports", "Cloud9", "Echo Fox",
                       "Team Liquid", "Golden Guardians", "TSM", "OpTic Gaming", "Counter Logic Gaming"]

# %% [markdown]
# ## Run Youtube API to query Channel ID's for Team Channel

# %%
#Parameters to narrow down the youtube's channel search
parameters = {"part": 'snippet',
              "type": "channel",
              "fields": 'items(id(channelId),snippet(publishedAt, channelId,description,channelTitle))',
              "maxResults": 1,
              "key": API_Key
             }

# %%
#Create an empy list that will be used to store information on the for-loop
channel_ID = []
channel_Title = []
about = []
published = []

# %%
url_channel = 'https://www.googleapis.com/youtube/v3/search'

# %%
#For-Loop to go through all the team's official youtube channels
for team_channel in teams_Youtube_Channels:
    
    parameters["q"] = team_channel
    #Contruct the finalize url with its parameters and create a request
    #Parse the queried data to json
    info = requests.get(url_channel, params=parameters).json()
    
    #Append the queried data to the initialize list before the for-loop
    channel_ID.append(info['items'][0]['id']['channelId'])
    channel_Title.append(info['items'][0]['snippet']['channelTitle'])
    about.append(info['items'][0]['snippet']['description'])
    published.append(info['items'][0]['snippet']['publishedAt'])

# %%
#Channel Information
channels = pd.DataFrame({
                    "Team Channel": channel_Title,
                    "About": about,
                    "Date Created": published,
                    "Channel ID": channel_ID}
                    )

# %%
channels = channels[['Team Channel','Channel ID', 'About', 'Date Created']]
channels
# Out:
#              Team Channel                Channel ID  \
# 0                fnaticTV  UCxo56gzJQ_fhb6svPqTSewg
# 1              G2 Esports  UCs9Bi1j5s25Yinhmd-NJvJw
# 2                  Splyce  UC30f1UTFNXfcGcrsojwOpSw
# 3           Team Vitality  UCgjhed4ZWlmC25hS4Sgs7gw
# 4                  ROCCAT  UCJYOx0a2eU_lKmYAOX7Cxxw
# 5          Misfits Gaming  UCNlfMcV8ettCBDXP3MQMM6Q
# 6                     H2K  UCPeD5OWc42p-Rhq7_HKQ4WA
# 7   FC Schalke 04 Esports  UCW5NJHURAfjEywb_2SOlrbA
# 8           Giants Gaming  UCgwqIJ1iCyIe49CPUe6iqfQ
# 9        Unicorns of Love  UCKe45PmvzzQTmh5-d1kJ-qg
# 10            100 Thieves  UCnrX2_FoKieobtw19PiphDw
# 11          Clutch Gaming  UCzXSr6GhwE24RqGpQYxp-1g
# 12        FlyQuest Sports  UCy0omD6TIJklBme14VQqV6A
# 13                 Cloud9  UCEkorHXUNJ5tpcH0VE77_fA
# 14               Echo Fox  UCNUKTjgmA5gPwrUYmdgfqvw
# 15            Team Liquid  UCLSWNf28X3mVTxTT3_nLCcw
# 16       Golden Guardians  UCV3_tt-m96bNztRaDAkPc-g
# 17                    TSM  UC4Ndz98NI_-9VQM3E7fctnQ
# 18           OpTic Gaming  UCVhkzoReyB25jpFEeXjh3kQ
# 19   Counter Logic Gaming  UCUYdOka3TBY0OV75AkiuMRw
#
#                                                 About  \
# 0   Fnatic is a leading eSports organisation compe...
# 1   G2 Esports is a World Premier eSports Club fou...
# 2   Splyce, founded in 2015, is home to top level ...
# 3
# 4   WE ARE ROCCAT, YOU ARE ROCCAT We are gamers, l...
# 5   Official YouTube of the premium esports organi...
# 6
# 7   Find behind the scene insights of our boot cam...
# 8   Welcome to the official channel of the Giants,...
# 9   The Official YouTube Channel of European LCS T...
# 10  Website: https://100Thieves.com ▻ Twitter: htt...
# 11  Official YouTube channel for Clutch Gaming, an...
# 12
# 13            The Official Youtube Channel of Cloud9.
# 14  Echo Fox is a premier eSports group with elite...
# 15  Skill. Passion. Content. The best pro-gaming t...
# 16  Official Account of the Golden Guardians LCS T...
# 17  Team SoloMid is the most popular esports organ...
# 18  The Global Leader in Gaming Entertainment. Sto...
# 19  CLG is a premiere esports gaming organization ...
#
#                 Date Created
# 0   2007-09-01T23:18:11.000Z
# 1   2014-01-20T18:41:30.000Z
# 2   2015-12-19T17:12:43.000Z
# 3   2015-12-09T13:36:53.000Z
# 4   2009-06-26T07:31:53.000Z
# 5   2016-11-23T12:04:14.000Z
# 6   2016-05-16T10:29:09.000Z
# 7   2016-10-24T09:50:41.000Z
# 8   2010-06-05T21:44:04.000Z
# 9   2014-03-20T18:08:48.000Z
# 10  2017-10-18T19:21:34.000Z
# 11  2018-02-19T19:25:43.000Z
# 12  2017-04-08T01:46:53.000Z
# 13  2013-06-17T03:14:59.000Z
# 14  2015-12-19T21:02:20.000Z
# 15  2015-01-04T21:02:57.000Z
# 16  2017-11-13T23:18:47.000Z
# 17  2010-01-04T06:48:49.000Z
# 18  2009-09-05T03:48:36.000Z
# 19  2011-04-01T04:22:19.000Z

# %%
#Create a KV-pair
channel_KV = dict(zip(channel_ID, channel_Title))

# %%
#Request Youtube API to create Channel statistics response

# %%
#Parameters to narrow down the youtube's channel search
parameters = {"part": 'statistics',
              "fields":'items(statistics )',
              "maxResults": 1,
              "key": API_Key
             }

# %%
channelStat_url = 'https://www.googleapis.com/youtube/v3/channels'

# %%
count_channel_statistics = []

# %%
#For-Loop to go through all the team's official youtube channels
for k, v in channel_KV.items():
    parameters["id"] = k
    #Contruct the finalize url with its parameters and create a request
    #Parse the queried data to json
    stat = requests.get(channelStat_url, params=parameters).json()
    
    count_channel_statistics.append({"Team Channel": v,
                                     "View Count": stat['items'][0]['statistics']['viewCount'],
                                     "Subscriber Count": stat['items'][0]['statistics']['subscriberCount'],
                                     "Video Count": stat['items'][0]['statistics']['videoCount']})

# %%
team_statistics_df = pd.DataFrame.from_dict(count_channel_statistics)
team_statistics_df
# Out:
#    Subscriber Count           Team Channel Video Count View Count
# 0            323055               fnaticTV        1466   35206932
# 1             88377             G2 Esports         283    6986816
# 2             10899                 Splyce         299     532944
# 3             34711          Team Vitality          55    1726501
# 4            177314                 ROCCAT         429   12217151
# 5              9936         Misfits Gaming          54     850203
# 6             21115                    H2K         195    2766812
# 7              3619  FC Schalke 04 Esports          17     217142
# 8             22091          Giants Gaming         312    1331141
# 9             20321       Unicorns of Love         106    1518106
# 10           139436            100 Thieves          16    2672540
# 11             2237          Clutch Gaming           6      54715
# 12             4130        FlyQuest Sports          39     193453
# 13           204100                 Cloud9         534   20283766
# 14            16681               Echo Fox         105     972307
# 15           113649            Team Liquid         332   12603030
# 16             1808       Golden Guardians          21      80925
# 17           693327                    TSM        1230  147565848
# 18          1410360           OpTic Gaming        1091  113306800
# 19            69466   Counter Logic Gaming         183    5201590

# %%
data = pd.merge(channels, team_statistics_df)
data
# Out:
#              Team Channel                Channel ID  \
# 0                fnaticTV  UCxo56gzJQ_fhb6svPqTSewg
# 1              G2 Esports  UCs9Bi1j5s25Yinhmd-NJvJw
# 2                  Splyce  UC30f1UTFNXfcGcrsojwOpSw
# 3           Team Vitality  UCgjhed4ZWlmC25hS4Sgs7gw
# 4                  ROCCAT  UCJYOx0a2eU_lKmYAOX7Cxxw
# 5          Misfits Gaming  UCNlfMcV8ettCBDXP3MQMM6Q
# 6                     H2K  UCPeD5OWc42p-Rhq7_HKQ4WA
# 7   FC Schalke 04 Esports  UCW5NJHURAfjEywb_2SOlrbA
# 8           Giants Gaming  UCgwqIJ1iCyIe49CPUe6iqfQ
# 9        Unicorns of Love  UCKe45PmvzzQTmh5-d1kJ-qg
# 10            100 Thieves  UCnrX2_FoKieobtw19PiphDw
# 11          Clutch Gaming  UCzXSr6GhwE24RqGpQYxp-1g
# 12        FlyQuest Sports  UCy0omD6TIJklBme14VQqV6A
# 13                 Cloud9  UCEkorHXUNJ5tpcH0VE77_fA
# 14               Echo Fox  UCNUKTjgmA5gPwrUYmdgfqvw
# 15            Team Liquid  UCLSWNf28X3mVTxTT3_nLCcw
# 16       Golden Guardians  UCV3_tt-m96bNztRaDAkPc-g
# 17                    TSM  UC4Ndz98NI_-9VQM3E7fctnQ
# 18           OpTic Gaming  UCVhkzoReyB25jpFEeXjh3kQ
# 19   Counter Logic Gaming  UCUYdOka3TBY0OV75AkiuMRw
#
#                                                 About  \
# 0   Fnatic is a leading eSports organisation compe...
# 1   G2 Esports is a World Premier eSports Club fou...
# 2   Splyce, founded in 2015, is home to top level ...
# 3
# 4   WE ARE ROCCAT, YOU ARE ROCCAT We are gamers, l...
# 5   Official YouTube of the premium esports organi...
# 6
# 7   Find behind the scene insights of our boot cam...
# 8   Welcome to the official channel of the Giants,...
# 9   The Official YouTube Channel of European LCS T...
# 10  Website: https://100Thieves.com ▻ Twitter: htt...
# 11  Official YouTube channel for Clutch Gaming, an...
# 12
# 13            The Official Youtube Channel of Cloud9.
# 14  Echo Fox is a premier eSports group with elite...
# 15  Skill. Passion. Content. The best pro-gaming t...
# 16  Official Account of the Golden Guardians LCS T...
# 17  Team SoloMid is the most popular esports organ...
# 18  The Global Leader in Gaming Entertainment. Sto...
# 19  CLG is a premiere esports gaming organization ...
#
#                 Date Created Subscriber Count Video Count View Count
# 0   2007-09-01T23:18:11.000Z           323055        1466   35206932
# 1   2014-01-20T18:41:30.000Z            88377         283    6986816
# 2   2015-12-19T17:12:43.000Z            10899         299     532944
# 3   2015-12-09T13:36:53.000Z            34711          55    1726501
# 4   2009-06-26T07:31:53.000Z           177314         429   12217151
# 5   2016-11-23T12:04:14.000Z             9936          54     850203
# 6   2016-05-16T10:29:09.000Z            21115         195    2766812
# 7   2016-10-24T09:50:41.000Z             3619          17     217142
# 8   2010-06-05T21:44:04.000Z            22091         312    1331141
# 9   2014-03-20T18:08:48.000Z            20321         106    1518106
# 10  2017-10-18T19:21:34.000Z           139436          16    2672540
# 11  2018-02-19T19:25:43.000Z             2237           6      54715
# 12  2017-04-08T01:46:53.000Z             4130          39     193453
# 13  2013-06-17T03:14:59.000Z           204100         534   20283766
# 14  2015-12-19T21:02:20.000Z            16681         105     972307
# 15  2015-01-04T21:02:57.000Z           113649         332   12603030
# 16  2017-11-13T23:18:47.000Z             1808          21      80925
# 17  2010-01-04T06:48:49.000Z           693327        1230  147565848
# 18  2009-09-05T03:48:36.000Z          1410360        1091  113306800
# 19  2011-04-01T04:22:19.000Z            69466         183    5201590

# %%
#Save the responses to Resources folder
with open('Resources/Team_channel_stats.json', 'w') as outfile:
    json.dump(count_channel_statistics, outfile)

# %%
#Request Youtube API to get comments and replies

# %%
#Parameters to narrow down the youtube's channel search
parameters = {"part": 'snippet,replies',
              "fields": 'nextPageToken,pageInfo(totalResults),items(snippet(channelId,videoId,topLevelComment))',
              "maxResults": 100,
              "key": API_Key
             }

# %%
channelComment_url = 'https://www.googleapis.com/youtube/v3/commentThreads'

# %%
sentiments = []
final=[]

for k, v in channel_KV.items():
    parameters["allThreadsRelatedToChannelId"] = k
    comments = requests.get(channelComment_url, params=parameters).json()
    
    counter = 1
    
    for x in range (comments['pageInfo']['totalResults']):
        comment = comments['items'][x]['snippet']['topLevelComment']['snippet']['textDisplay']
        published = comments['items'][x]['snippet']['topLevelComment']['snippet']['publishedAt']

        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(comment)["compound"]
        pos = analyzer.polarity_scores(comment)["pos"]
        neu = analyzer.polarity_scores(comment)["neu"]
        neg = analyzer.polarity_scores(comment)["neg"]

        # Add sentiments for each tweet into an array
        sentiments.append({"Channel Title": v,
                           "Comments":comment,
                           "Published": published,
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Comment Count ": counter})
        # Add to counter 
        counter += 1

# %%
sentiments_df = pd.DataFrame.from_dict(sentiments)
sentiments_df
# Out:
#              Channel Title  Comment Count   \
# 0                 fnaticTV               1
# 1                 fnaticTV               2
# 2                 fnaticTV               3
# 3                 fnaticTV               4
# 4                 fnaticTV               5
# 5                 fnaticTV               6
# 6                 fnaticTV               7
# 7                 fnaticTV               8
# 8                 fnaticTV               9
# 9                 fnaticTV              10
# 10                fnaticTV              11
# 11                fnaticTV              12
# 12                fnaticTV              13
# 13                fnaticTV              14
# 14                fnaticTV              15
# 15                fnaticTV              16
# 16                fnaticTV              17
# 17                fnaticTV              18
# 18                fnaticTV              19
# 19                fnaticTV              20
# 20                fnaticTV              21
# 21                fnaticTV              22
# 22                fnaticTV              23
# 23                fnaticTV              24
# 24                fnaticTV              25
# 25                fnaticTV              26
# 26                fnaticTV              27
# 27                fnaticTV              28
# 28                fnaticTV              29
# 29                fnaticTV              30
# ...                    ...             ...
# 1962  Counter Logic Gaming              71
# 1963  Counter Logic Gaming              72
# 1964  Counter Logic Gaming              73
# 1965  Counter Logic Gaming              74
# 1966  Counter Logic Gaming              75
# 1967  Counter Logic Gaming              76
# 1968  Counter Logic Gaming              77
# 1969  Counter Logic Gaming              78
# 1970  Counter Logic Gaming              79
# 1971  Counter Logic Gaming              80
# 1972  Counter Logic Gaming              81
# 1973  Counter Logic Gaming              82
# 1974  Counter Logic Gaming              83
# 1975  Counter Logic Gaming              84
# 1976  Counter Logic Gaming              85
# 1977  Counter Logic Gaming              86
# 1978  Counter Logic Gaming              87
# 1979  Counter Logic Gaming              88
# 1980  Counter Logic Gaming              89
# 1981  Counter Logic Gaming              90
# 1982  Counter Logic Gaming              91
# 1983  Counter Logic Gaming              92
# 1984  Counter Logic Gaming              93
# 1985  Counter Logic Gaming              94
# 1986  Counter Logic Gaming              95
# 1987  Counter Logic Gaming              96
# 1988  Counter Logic Gaming              97
# 1989  Counter Logic Gaming              98
# 1990  Counter Logic Gaming              99
# 1991  Counter Logic Gaming             100
#
#                                                Comments  Compound  Negative  \
# 0                            anyone got any help/hints?    0.0000     1.000
# 1     jesus christ i finished the whole game. That w...    0.8742     0.477
# 2            Update did anyone found this or any clue ?    0.0000     1.000
# 3                                                     C    0.0000     0.000
# 4                                    anyone knows next?    0.0000     1.000
# 5      i need help to find the next one, please fnatic.    0.6124     0.583
# 6                                           i found it.    0.0000     1.000
# 7                                          Lets go boyz    0.0000     1.000
# 8                                    Anyone knows next?    0.0000     1.000
# 9     Jesiz my man, you made me rofl in this video. ...    0.5719     0.764
# 10                                           Next clue?    0.0000     1.000
# 11                                 here up its the clue    0.0000     1.000
# 12                                           next clue?    0.0000     1.000
# 13    Pretty sure the Easter egg hunt leads here... ...    0.7311     0.505
# 14                                Pff that clue, sneaky   -0.2263     0.612
# 15                             what song is that called    0.0000     1.000
# 16                             I do sleep. In minecraft    0.0000     1.000
# 17    i can not find the first song using the title ...    0.6682     0.814
# 18                                          Gooooddddss    0.0000     1.000
# 19                                                👍nice    0.0000     1.000
# 20                         lol the fuckin t shirt remix    0.4215     0.588
# 21                                          ESKIIT SKRR    0.0000     1.000
# 22    so u gonna win everything now until the next k...    0.8581     0.565
# 23    Nice edit, really enjoyed the Flusha clutch part!    0.7707     0.473
# 24    Seriously I&#39;m gonna fuck*ng cry if Fnatic ...   -0.0258     0.452
# 25    Happy to hear that Golden still &quot; Xzists&...    0.5719     0.709
# 26    <a href="http://www.youtube.com/results?search...    0.0000     1.000
# 27                                           PAPA KRIMZ    0.0000     1.000
# 28                          Fnatic was it 2017 or 2018?    0.0000     1.000
# 29                                      Unos grandes...    0.0000     1.000
# ...                                                 ...       ...       ...
# 1962  <a href="http://www.youtube.com/results?search...    0.0000     1.000
# 1963        I like this type of content. :D CLGFIGHTING    0.7603     0.434
# 1964  what I learn from pewdiepie , 10min video = ad...    0.0000     1.000
# 1965               &quot;OPenis&quot; gets me everytime    0.0000     1.000
# 1966          what is the song that plays at the start?    0.2500     0.800
# 1967                    Wtf did Tony say at the end LUL   -0.5859     0.648
# 1968                        no max range on E I love it    0.4588     0.385
# 1969                      RUNE*<b>**</b> MAGE YOU FUCKS   -0.5904     0.439
# 1970  &quot;I do not wanna play against it&quot; - t...    0.5419     0.709
# 1971               &quot;That&#39;s my 2D girl&quot; 😂😂    0.0000     1.000
# 1972  She&#39;s definitely going to be the sort of c...    0.7850     0.639
# 1973  U know that darshan already looking on How to ...    0.6739     0.708
# 1974       CLG GANG<br /><br /><br /><br />GANG GANG!!!    0.0000     1.000
# 1975  <a href="https://www.youtube.com/watch?v=xliB8...    0.0000     1.000
# 1976  <a href="https://www.youtube.com/watch?v=xliB8...   -0.7550     0.684
# 1977  Been a fan of the org since 2010/2011 and I wi...    0.4767     0.760
# 1978                                   I love you guys!    0.6696     0.308
# 1979  Loved how Zikz&#39;s desktop background was Gr...    0.5994     0.606
# 1980  I believe the last 2 losses came from seing ts...    0.4576     0.807
# 1981                                summer split though    0.0000     1.000
# 1982  It&#39;s never easy, but <a href="http://www.y...   -0.1786     0.746
# 1983       Lets do it bois! Lets fck them up in summer.    0.0000     1.000
# 1984  I still believe in this team and that this tea...    0.5399     0.886
# 1985  Hey IMT ended 7th spring split but then went t...    0.0000     1.000
# 1986  Is Tony planning o getting a flame thrower? Lo...    0.6369     0.741
# 1987  You guys got this. Don&#39;t let this derail t...   -0.8172     0.681
# 1988                                  We can do this!💪🏼    0.0000     1.000
# 1989  LipStixxay <a href="https://www.youtube.com/wa...    0.0000     1.000
# 1990  I don&#39;t like that the performance coach fe...   -0.2716     0.803
# 1991  Step #1: Get Aphromoo back. Duh. Well, I suppo...    0.2732     0.851
#
#       Neutral  Positive                 Published
# 0       0.000     0.000  2018-03-30T17:27:16.000Z
# 1       0.000     0.523  2018-03-30T17:02:38.000Z
# 2       0.000     0.000  2018-03-30T16:17:01.000Z
# 3       0.000     0.000  2018-03-30T15:46:22.000Z
# 4       0.000     0.000  2018-03-30T15:38:32.000Z
# 5       0.000     0.417  2018-03-30T15:37:45.000Z
# 6       0.000     0.000  2018-03-30T15:37:33.000Z
# 7       0.000     0.000  2018-03-30T15:29:58.000Z
# 8       0.000     0.000  2018-03-30T15:26:04.000Z
# 9       0.000     0.236  2018-03-30T15:09:18.000Z
# 10      0.000     0.000  2018-03-30T14:41:05.000Z
# 11      0.000     0.000  2018-03-30T14:38:36.000Z
# 12      0.000     0.000  2018-03-30T14:22:38.000Z
# 13      0.118     0.377  2018-03-30T14:19:17.000Z
# 14      0.388     0.000  2018-03-30T14:08:42.000Z
# 15      0.000     0.000  2018-03-28T22:44:18.000Z
# 16      0.000     0.000  2018-03-28T17:12:54.000Z
# 17      0.000     0.186  2018-03-28T11:24:44.000Z
# 18      0.000     0.000  2018-03-25T02:47:19.000Z
# 19      0.000     0.000  2018-03-25T00:27:52.000Z
# 20      0.000     0.412  2018-03-25T00:06:46.000Z
# 21      0.000     0.000  2018-03-24T23:46:02.000Z
# 22      0.000     0.435  2018-03-24T20:44:55.000Z
# 23      0.000     0.527  2018-03-24T19:01:39.000Z
# 24      0.310     0.239  2018-03-24T18:09:32.000Z
# 25      0.000     0.291  2018-03-24T16:51:56.000Z
# 26      0.000     0.000  2018-03-24T16:48:37.000Z
# 27      0.000     0.000  2018-03-24T16:31:28.000Z
# 28      0.000     0.000  2018-03-24T15:58:55.000Z
# 29      0.000     0.000  2018-03-24T15:55:32.000Z
# ...       ...       ...                       ...
# 1962    0.000     0.000  2018-03-25T12:48:38.000Z
# 1963    0.000     0.566  2018-03-25T10:55:39.000Z
# 1964    0.000     0.000  2018-03-25T07:43:04.000Z
# 1965    0.000     0.000  2018-03-25T02:06:35.000Z
# 1966    0.000     0.200  2018-03-25T00:59:50.000Z
# 1967    0.352     0.000  2018-03-25T00:32:59.000Z
# 1968    0.212     0.404  2018-03-24T20:15:34.000Z
# 1969    0.561     0.000  2018-03-24T19:28:00.000Z
# 1970    0.090     0.201  2018-03-24T18:26:07.000Z
# 1971    0.000     0.000  2018-03-24T18:22:28.000Z
# 1972    0.000     0.361  2018-03-24T18:13:57.000Z
# 1973    0.000     0.292  2018-03-24T18:13:25.000Z
# 1974    0.000     0.000  2018-03-24T18:12:22.000Z
# 1975    0.000     0.000  2018-03-24T17:14:38.000Z
# 1976    0.316     0.000  2018-03-24T17:09:35.000Z
# 1977    0.000     0.240  2018-03-24T14:33:21.000Z
# 1978    0.000     0.692  2018-03-24T13:08:15.000Z
# 1979    0.000     0.394  2018-03-24T12:43:25.000Z
# 1980    0.081     0.113  2018-03-24T12:37:35.000Z
# 1981    0.000     0.000  2018-03-24T12:23:15.000Z
# 1982    0.254     0.000  2018-03-24T11:35:03.000Z
# 1983    0.000     0.000  2018-03-24T09:59:54.000Z
# 1984    0.000     0.114  2018-03-24T08:48:37.000Z
# 1985    0.000     0.000  2018-03-24T05:55:08.000Z
# 1986    0.000     0.259  2018-03-24T05:20:58.000Z
# 1987    0.319     0.000  2018-03-24T05:13:06.000Z
# 1988    0.000     0.000  2018-03-24T04:52:46.000Z
# 1989    0.000     0.000  2018-03-24T04:37:19.000Z
# 1990    0.127     0.069  2018-03-24T04:23:19.000Z
# 1991    0.000     0.149  2018-03-24T02:07:29.000Z
#
# [1992 rows x 8 columns]

# %%
sentiments_df.to_csv('Resources/comments.csv')
