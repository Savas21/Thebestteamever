# %%
#Dependencies
import json
import requests
import numpy as np
import pandas as pd
from youtube_api import API_Key
import itertools
import datetime as dt
import time
# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#List of channels that needs to query channel information
teams_Youtube_Channels=["fnaticTV","G2 Esports", "Splyce", "Team Vitality", "ROCCAT",
                       "Misfits Gaming", "H2K", "FC Schalke 04 Esports", "Giants Gaming","Unicorns Of Love",
                       "100 Thieves", "Clutch Gaming", "FlyQuest Sports", "Cloud9", "Echo Fox",
                       "Team Liquid", "Golden Guardians", "TSM", "OpTic Gaming", "Counter Logic Gaming"]

# %% [markdown]
# ## Run Youtube API to query Channel ID's for Team Channel

# %%
#Parameters to narrow down the youtube's channel search
parameters = {"part": 'snippet',
              "type": "channel",
              "fields": 'items(id(channelId),snippet(publishedAt, channelId,description,channelTitle))',
              "maxResults": 1,
              "key": API_Key
             }

# %%
#Create an empy list that will be used to store information on the for-loop
channel_ID = []
channel_Title = []
about = []
published = []

# %%
url_channel = 'https://www.googleapis.com/youtube/v3/search'

# %%
#For-Loop to go through all the team's official youtube channels
for team_channel in teams_Youtube_Channels:
    
    parameters["q"] = team_channel
    #Contruct the finalize url with its parameters and create a request
    #Parse the queried data to json
    info = requests.get(url_channel, params=parameters).json()
    
    #Append the queried data to the initialize list before the for-loop
    channel_ID.append(info['items'][0]['id']['channelId'])
    channel_Title.append(info['items'][0]['snippet']['channelTitle'])
    about.append(info['items'][0]['snippet']['description'])
    published.append(info['items'][0]['snippet']['publishedAt'])

# %%
#Channel Information
channels = pd.DataFrame({
                    "Team": channel_Title,
                    "About": about,
                    "Date Created": published,
                    "Channel ID": channel_ID}
                    )
channels
# Out:
#                                                 About  \
# 0   Fnatic is a leading eSports organisation compe...
# 1   G2 Esports is a World Premier eSports Club fou...
# 2   Splyce, founded in 2015, is home to top level ...
# 3
# 4   WE ARE ROCCAT, YOU ARE ROCCAT We are gamers, l...
# 5   Official YouTube of the premium esports organi...
# 6
# 7   Find behind the scene insights of our boot cam...
# 8   Welcome to the official channel of the Giants,...
# 9   The Official YouTube Channel of European LCS T...
# 10  Website: https://100Thieves.com ▻ Twitter: htt...
# 11  Official YouTube channel for Clutch Gaming, an...
# 12
# 13            The Official Youtube Channel of Cloud9.
# 14  Echo Fox is a premier eSports group with elite...
# 15  Skill. Passion. Content. The best pro-gaming t...
# 16  Official Account of the Golden Guardians LCS T...
# 17  Team SoloMid is the most popular esports organ...
# 18  The Global Leader in Gaming Entertainment. Sto...
# 19  CLG is a premiere esports gaming organization ...
#
#                   Channel ID              Date Created                   Team
# 0   UCxo56gzJQ_fhb6svPqTSewg  2007-09-01T23:18:11.000Z               fnaticTV
# 1   UCs9Bi1j5s25Yinhmd-NJvJw  2014-01-20T18:41:30.000Z             G2 Esports
# 2   UC30f1UTFNXfcGcrsojwOpSw  2015-12-19T17:12:43.000Z                 Splyce
# 3   UCgjhed4ZWlmC25hS4Sgs7gw  2015-12-09T13:36:53.000Z          Team Vitality
# 4   UCJYOx0a2eU_lKmYAOX7Cxxw  2009-06-26T07:31:53.000Z                 ROCCAT
# 5   UCNlfMcV8ettCBDXP3MQMM6Q  2016-11-23T12:04:14.000Z         Misfits Gaming
# 6   UCPeD5OWc42p-Rhq7_HKQ4WA  2016-05-16T10:29:09.000Z                    H2K
# 7   UCW5NJHURAfjEywb_2SOlrbA  2016-10-24T09:50:41.000Z  FC Schalke 04 Esports
# 8   UCgwqIJ1iCyIe49CPUe6iqfQ  2010-06-05T21:44:04.000Z          Giants Gaming
# 9   UCKe45PmvzzQTmh5-d1kJ-qg  2014-03-20T18:08:48.000Z       Unicorns of Love
# 10  UCnrX2_FoKieobtw19PiphDw  2017-10-18T19:21:34.000Z            100 Thieves
# 11  UCzXSr6GhwE24RqGpQYxp-1g  2018-02-19T19:25:43.000Z          Clutch Gaming
# 12  UCy0omD6TIJklBme14VQqV6A  2017-04-08T01:46:53.000Z        FlyQuest Sports
# 13  UCEkorHXUNJ5tpcH0VE77_fA  2013-06-17T03:14:59.000Z                 Cloud9
# 14  UCNUKTjgmA5gPwrUYmdgfqvw  2015-12-19T21:02:20.000Z               Echo Fox
# 15  UCLSWNf28X3mVTxTT3_nLCcw  2015-01-04T21:02:57.000Z            Team Liquid
# 16  UCV3_tt-m96bNztRaDAkPc-g  2017-11-13T23:18:47.000Z       Golden Guardians
# 17  UC4Ndz98NI_-9VQM3E7fctnQ  2010-01-04T06:48:49.000Z                    TSM
# 18  UCVhkzoReyB25jpFEeXjh3kQ  2009-09-05T03:48:36.000Z           OpTic Gaming
# 19  UCUYdOka3TBY0OV75AkiuMRw  2011-04-01T04:22:19.000Z   Counter Logic Gaming

# %%
#Rename the team names 

channels=channels.replace("FlyQuest Sports","FlyQuest")
channels=channels.replace("fnaticTV","Fnatic")
channels=channels.replace("Giants Gaming","Giants")
channels=channels.replace("Team Vitality","Vitality")
channels
# Out:
#                                                 About  \
# 0   Fnatic is a leading eSports organisation compe...
# 1   G2 Esports is a World Premier eSports Club fou...
# 2   Splyce, founded in 2015, is home to top level ...
# 3
# 4   WE ARE ROCCAT, YOU ARE ROCCAT We are gamers, l...
# 5   Official YouTube of the premium esports organi...
# 6
# 7   Find behind the scene insights of our boot cam...
# 8   Welcome to the official channel of the Giants,...
# 9   The Official YouTube Channel of European LCS T...
# 10  Website: https://100Thieves.com ▻ Twitter: htt...
# 11  Official YouTube channel for Clutch Gaming, an...
# 12
# 13            The Official Youtube Channel of Cloud9.
# 14  Echo Fox is a premier eSports group with elite...
# 15  Skill. Passion. Content. The best pro-gaming t...
# 16  Official Account of the Golden Guardians LCS T...
# 17  Team SoloMid is the most popular esports organ...
# 18  The Global Leader in Gaming Entertainment. Sto...
# 19  CLG is a premiere esports gaming organization ...
#
#                   Channel ID              Date Created                   Team
# 0   UCxo56gzJQ_fhb6svPqTSewg  2007-09-01T23:18:11.000Z                 Fnatic
# 1   UCs9Bi1j5s25Yinhmd-NJvJw  2014-01-20T18:41:30.000Z             G2 Esports
# 2   UC30f1UTFNXfcGcrsojwOpSw  2015-12-19T17:12:43.000Z                 Splyce
# 3   UCgjhed4ZWlmC25hS4Sgs7gw  2015-12-09T13:36:53.000Z               Vitality
# 4   UCJYOx0a2eU_lKmYAOX7Cxxw  2009-06-26T07:31:53.000Z                 ROCCAT
# 5   UCNlfMcV8ettCBDXP3MQMM6Q  2016-11-23T12:04:14.000Z         Misfits Gaming
# 6   UCPeD5OWc42p-Rhq7_HKQ4WA  2016-05-16T10:29:09.000Z                    H2K
# 7   UCW5NJHURAfjEywb_2SOlrbA  2016-10-24T09:50:41.000Z  FC Schalke 04 Esports
# 8   UCgwqIJ1iCyIe49CPUe6iqfQ  2010-06-05T21:44:04.000Z                 Giants
# 9   UCKe45PmvzzQTmh5-d1kJ-qg  2014-03-20T18:08:48.000Z       Unicorns of Love
# 10  UCnrX2_FoKieobtw19PiphDw  2017-10-18T19:21:34.000Z            100 Thieves
# 11  UCzXSr6GhwE24RqGpQYxp-1g  2018-02-19T19:25:43.000Z          Clutch Gaming
# 12  UCy0omD6TIJklBme14VQqV6A  2017-04-08T01:46:53.000Z               FlyQuest
# 13  UCEkorHXUNJ5tpcH0VE77_fA  2013-06-17T03:14:59.000Z                 Cloud9
# 14  UCNUKTjgmA5gPwrUYmdgfqvw  2015-12-19T21:02:20.000Z               Echo Fox
# 15  UCLSWNf28X3mVTxTT3_nLCcw  2015-01-04T21:02:57.000Z            Team Liquid
# 16  UCV3_tt-m96bNztRaDAkPc-g  2017-11-13T23:18:47.000Z       Golden Guardians
# 17  UC4Ndz98NI_-9VQM3E7fctnQ  2010-01-04T06:48:49.000Z                    TSM
# 18  UCVhkzoReyB25jpFEeXjh3kQ  2009-09-05T03:48:36.000Z           OpTic Gaming
# 19  UCUYdOka3TBY0OV75AkiuMRw  2011-04-01T04:22:19.000Z   Counter Logic Gaming

# %%
#Create a KV-pair
channel_KV = dict(zip(channels["Channel ID"], channels["Team"]))

# %%
#Request Youtube API to create Channel statistics response

# %%
#Parameters to narrow down the youtube's channel search
parameters = {"part": 'statistics',
              "fields":'items(statistics )',
              "maxResults": 1,
              "key": API_Key
             }

# %%
channelStat_url = 'https://www.googleapis.com/youtube/v3/channels'

# %%
count_channel_statistics = []
#For-Loop to go through all the team's official youtube channels
for k, v in channel_KV.items():
    parameters["id"] = k
    #Contruct the finalize url with its parameters and create a request
    #Parse the queried data to json
    stat = requests.get(channelStat_url, params=parameters).json()
    
    count_channel_statistics.append({"Team": v,
                                     "View Count": stat['items'][0]['statistics']['viewCount'],
                                     "Subscriber Count": stat['items'][0]['statistics']['subscriberCount'],
                                     "Video Count": stat['items'][0]['statistics']['videoCount']})

# %%
team_statistics_df = pd.DataFrame.from_dict(count_channel_statistics)
team_statistics_df
# Out:
#    Subscriber Count                   Team Video Count View Count
# 0            323073                 Fnatic        1466   35207380
# 1             88430             G2 Esports         283    6988252
# 2             10903                 Splyce         299     532979
# 3             34766               Vitality          55    1734004
# 4            177313                 ROCCAT         429   12217414
# 5              9937         Misfits Gaming          54     850439
# 6             21116                    H2K         195    2766980
# 7              3619  FC Schalke 04 Esports          17     217155
# 8             22093                 Giants         312    1331208
# 9             20320       Unicorns of Love         106    1518114
# 10           139501            100 Thieves          16    2679560
# 11             2245          Clutch Gaming           6      55209
# 12             4129               FlyQuest          39     193456
# 13           204420                 Cloud9         534   20305310
# 14            16680               Echo Fox         105     972556
# 15           113675            Team Liquid         332   12608826
# 16             1808       Golden Guardians          21      80929
# 17           693435                    TSM        1230  147570008
# 18          1410355           OpTic Gaming        1092  113308492
# 19            69465   Counter Logic Gaming         183    5202114

# %%
team_statistics_df.to_csv('Resources/team_statistics_df.csv')

# %%
data = pd.merge(channels, team_statistics_df)
data
# Out:
#                                                 About  \
# 0   Fnatic is a leading eSports organisation compe...
# 1   G2 Esports is a World Premier eSports Club fou...
# 2   Splyce, founded in 2015, is home to top level ...
# 3
# 4   WE ARE ROCCAT, YOU ARE ROCCAT We are gamers, l...
# 5   Official YouTube of the premium esports organi...
# 6
# 7   Find behind the scene insights of our boot cam...
# 8   Welcome to the official channel of the Giants,...
# 9   The Official YouTube Channel of European LCS T...
# 10  Website: https://100Thieves.com ▻ Twitter: htt...
# 11  Official YouTube channel for Clutch Gaming, an...
# 12
# 13            The Official Youtube Channel of Cloud9.
# 14  Echo Fox is a premier eSports group with elite...
# 15  Skill. Passion. Content. The best pro-gaming t...
# 16  Official Account of the Golden Guardians LCS T...
# 17  Team SoloMid is the most popular esports organ...
# 18  The Global Leader in Gaming Entertainment. Sto...
# 19  CLG is a premiere esports gaming organization ...
#
#                   Channel ID              Date Created                   Team  \
# 0   UCxo56gzJQ_fhb6svPqTSewg  2007-09-01T23:18:11.000Z                 Fnatic
# 1   UCs9Bi1j5s25Yinhmd-NJvJw  2014-01-20T18:41:30.000Z             G2 Esports
# 2   UC30f1UTFNXfcGcrsojwOpSw  2015-12-19T17:12:43.000Z                 Splyce
# 3   UCgjhed4ZWlmC25hS4Sgs7gw  2015-12-09T13:36:53.000Z               Vitality
# 4   UCJYOx0a2eU_lKmYAOX7Cxxw  2009-06-26T07:31:53.000Z                 ROCCAT
# 5   UCNlfMcV8ettCBDXP3MQMM6Q  2016-11-23T12:04:14.000Z         Misfits Gaming
# 6   UCPeD5OWc42p-Rhq7_HKQ4WA  2016-05-16T10:29:09.000Z                    H2K
# 7   UCW5NJHURAfjEywb_2SOlrbA  2016-10-24T09:50:41.000Z  FC Schalke 04 Esports
# 8   UCgwqIJ1iCyIe49CPUe6iqfQ  2010-06-05T21:44:04.000Z                 Giants
# 9   UCKe45PmvzzQTmh5-d1kJ-qg  2014-03-20T18:08:48.000Z       Unicorns of Love
# 10  UCnrX2_FoKieobtw19PiphDw  2017-10-18T19:21:34.000Z            100 Thieves
# 11  UCzXSr6GhwE24RqGpQYxp-1g  2018-02-19T19:25:43.000Z          Clutch Gaming
# 12  UCy0omD6TIJklBme14VQqV6A  2017-04-08T01:46:53.000Z               FlyQuest
# 13  UCEkorHXUNJ5tpcH0VE77_fA  2013-06-17T03:14:59.000Z                 Cloud9
# 14  UCNUKTjgmA5gPwrUYmdgfqvw  2015-12-19T21:02:20.000Z               Echo Fox
# 15  UCLSWNf28X3mVTxTT3_nLCcw  2015-01-04T21:02:57.000Z            Team Liquid
# 16  UCV3_tt-m96bNztRaDAkPc-g  2017-11-13T23:18:47.000Z       Golden Guardians
# 17  UC4Ndz98NI_-9VQM3E7fctnQ  2010-01-04T06:48:49.000Z                    TSM
# 18  UCVhkzoReyB25jpFEeXjh3kQ  2009-09-05T03:48:36.000Z           OpTic Gaming
# 19  UCUYdOka3TBY0OV75AkiuMRw  2011-04-01T04:22:19.000Z   Counter Logic Gaming
#
#    Subscriber Count Video Count View Count
# 0            323073        1466   35207380
# 1             88430         283    6988252
# 2             10903         299     532979
# 3             34766          55    1734004
# 4            177313         429   12217414
# 5              9937          54     850439
# 6             21116         195    2766980
# 7              3619          17     217155
# 8             22093         312    1331208
# 9             20320         106    1518114
# 10           139501          16    2679560
# 11             2245           6      55209
# 12             4129          39     193456
# 13           204420         534   20305310
# 14            16680         105     972556
# 15           113675         332   12608826
# 16             1808          21      80929
# 17           693435        1230  147570008
# 18          1410355        1092  113308492
# 19            69465         183    5202114

# %%
#Save the responses to Resources folder
with open('Resources/Team_channel_stats.json', 'w') as outfile:
    json.dump(count_channel_statistics, outfile)

# %%
#Request Youtube API to get comments and replies

# %%
#Parameters to narrow down the youtube's channel search
parameters = {"part": 'snippet,replies',
              "fields": 'nextPageToken,pageInfo(totalResults),items(snippet(channelId,videoId,topLevelComment))',
              "maxResults": 100,
              "key": API_Key
             }

# %%
channelComment_url = 'https://www.googleapis.com/youtube/v3/commentThreads'

# %%
sentiments = []


for k, v in channel_KV.items():
    parameters["allThreadsRelatedToChannelId"] = k
    comments = requests.get(channelComment_url, params=parameters).json()
    
    counter = 1
    
    for x in range (comments['pageInfo']['totalResults']):
        comment = comments['items'][x]['snippet']['topLevelComment']['snippet']['textDisplay']
        published = comments['items'][x]['snippet']['topLevelComment']['snippet']['publishedAt']

        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(comment)["compound"]
        pos = analyzer.polarity_scores(comment)["pos"]
        neu = analyzer.polarity_scores(comment)["neu"]
        neg = analyzer.polarity_scores(comment)["neg"]

        # Add sentiments for each tweet into an array
        sentiments.append({"Team": v,
                           "Comments":comment,
                           "Published": published,
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Comment Count ": counter})
        # Add to counter 
        counter += 1

# %%
sentiments_df = pd.DataFrame.from_dict(sentiments)
sentiments_df
# Out:
#       Comment Count                                            Comments  \
# 0                  1                         anyone got any help/hints?
# 1                  2  jesus christ i finished the whole game. That w...
# 2                  3         Update did anyone found this or any clue ?
# 3                  4                                                  C
# 4                  5                                 anyone knows next?
# 5                  6   i need help to find the next one, please fnatic.
# 6                  7                                        i found it.
# 7                  8                                       Lets go boyz
# 8                  9                                 Anyone knows next?
# 9                 10  Jesiz my man, you made me rofl in this video. ...
# 10                11                                         Next clue?
# 11                12                               here up its the clue
# 12                13                                         next clue?
# 13                14  Pretty sure the Easter egg hunt leads here... ...
# 14                15                              Pff that clue, sneaky
# 15                16                           what song is that called
# 16                17                           I do sleep. In minecraft
# 17                18  i can not find the first song using the title ...
# 18                19                                        Gooooddddss
# 19                20                                              👍nice
# 20                21                       lol the fuckin t shirt remix
# 21                22                                        ESKIIT SKRR
# 22                23  so u gonna win everything now until the next k...
# 23                24  Nice edit, really enjoyed the Flusha clutch part!
# 24                25  Seriously I&#39;m gonna fuck*ng cry if Fnatic ...
# 25                26  Happy to hear that Golden still &quot; Xzists&...
# 26                27  <a href="http://www.youtube.com/results?search...
# 27                28                                         PAPA KRIMZ
# 28                29                        Fnatic was it 2017 or 2018?
# 29                30                                    Unos grandes...
# ...              ...                                                ...
# 1962              71  <a href="http://www.youtube.com/results?search...
# 1963              72        I like this type of content. :D CLGFIGHTING
# 1964              73  what I learn from pewdiepie , 10min video = ad...
# 1965              74               &quot;OPenis&quot; gets me everytime
# 1966              75          what is the song that plays at the start?
# 1967              76                    Wtf did Tony say at the end LUL
# 1968              77                        no max range on E I love it
# 1969              78                      RUNE*<b>**</b> MAGE YOU FUCKS
# 1970              79  &quot;I do not wanna play against it&quot; - t...
# 1971              80               &quot;That&#39;s my 2D girl&quot; 😂😂
# 1972              81  She&#39;s definitely going to be the sort of c...
# 1973              82  U know that darshan already looking on How to ...
# 1974              83       CLG GANG<br /><br /><br /><br />GANG GANG!!!
# 1975              84  <a href="https://www.youtube.com/watch?v=xliB8...
# 1976              85  <a href="https://www.youtube.com/watch?v=xliB8...
# 1977              86  Been a fan of the org since 2010/2011 and I wi...
# 1978              87                                   I love you guys!
# 1979              88  Loved how Zikz&#39;s desktop background was Gr...
# 1980              89  I believe the last 2 losses came from seing ts...
# 1981              90                                summer split though
# 1982              91  It&#39;s never easy, but <a href="http://www.y...
# 1983              92       Lets do it bois! Lets fck them up in summer.
# 1984              93  I still believe in this team and that this tea...
# 1985              94  Hey IMT ended 7th spring split but then went t...
# 1986              95  Is Tony planning o getting a flame thrower? Lo...
# 1987              96  You guys got this. Don&#39;t let this derail t...
# 1988              97                                  We can do this!💪🏼
# 1989              98  LipStixxay <a href="https://www.youtube.com/wa...
# 1990              99  I don&#39;t like that the performance coach fe...
# 1991             100  Step #1: Get Aphromoo back. Duh. Well, I suppo...
#
# 1976  Counter Logic Gaming
# 1977  Counter Logic Gaming
# 1978  Counter Logic Gaming
# 1979  Counter Logic Gaming
# 1980  Counter Logic Gaming
# 1981  Counter Logic Gaming
# 1982  Counter Logic Gaming
# 1983  Counter Logic Gaming
# 1984  Counter Logic Gaming
# 1985  Counter Logic Gaming
# 1986  Counter Logic Gaming
# 1987  Counter Logic Gaming
# 1988  Counter Logic Gaming
# 1989  Counter Logic Gaming
# 1990  Counter Logic Gaming
# 1991  Counter Logic Gaming
#
# [1992 rows x 8 columns]

# %%
sentiments_df.to_csv('Resources/comments.csv')

# %%
sentiments_df_summary =sentiments_df.groupby(["Team"]).mean()["Compound"]
sentiments_df_summary =pd.DataFrame(sentiments_df_summary)
sentiments_df_summary.reset_index(level=0,inplace=True)
sentiments_df=sentiments_df.set_index("Team")
sentiments_df_summary
# Out:
#                      Team  Compound
# 0             100 Thieves  0.355807
# 1                  Cloud9  0.012018
# 2           Clutch Gaming  0.249024
# 3    Counter Logic Gaming  0.127185
# 4                Echo Fox  0.121082
# 5   FC Schalke 04 Esports  0.193417
# 6                FlyQuest  0.274111
# 7                  Fnatic  0.200500
# 8              G2 Esports  0.157671
# 9                  Giants  0.012209
# 10       Golden Guardians  0.304155
# 11                    H2K  0.146872
# 12         Misfits Gaming  0.443267
# 13           OpTic Gaming  0.173041
# 14                 ROCCAT  0.108620
# 15                 Splyce  0.313538
# 16                    TSM  0.143173
# 17            Team Liquid  0.228083
# 18       Unicorns of Love  0.397646
# 19               Vitality  0.055084

# %%
sentiments_df_summary.to_csv('Resources/sentiments_df_summary.csv')

# %%
## Merge two data  
Youtube_Data = pd.merge(data,sentiments_df_summary)
#team_sentiment_df=team_sentiment_df.set_index("Team")
Youtube_Data.set_index("Team")
# Out:
#                                                                    About  \
# Team
# Fnatic                 Fnatic is a leading eSports organisation compe...
# G2 Esports             G2 Esports is a World Premier eSports Club fou...
# Splyce                 Splyce, founded in 2015, is home to top level ...
# Vitality
# ROCCAT                 WE ARE ROCCAT, YOU ARE ROCCAT We are gamers, l...
# Misfits Gaming         Official YouTube of the premium esports organi...
# H2K
# FC Schalke 04 Esports  Find behind the scene insights of our boot cam...
# Giants                 Welcome to the official channel of the Giants,...
# Unicorns of Love       The Official YouTube Channel of European LCS T...
# 100 Thieves            Website: https://100Thieves.com ▻ Twitter: htt...
# Clutch Gaming          Official YouTube channel for Clutch Gaming, an...
# FlyQuest
# Cloud9                           The Official Youtube Channel of Cloud9.
# Echo Fox               Echo Fox is a premier eSports group with elite...
# Team Liquid            Skill. Passion. Content. The best pro-gaming t...
# Golden Guardians       Official Account of the Golden Guardians LCS T...
# TSM                    Team SoloMid is the most popular esports organ...
# OpTic Gaming           The Global Leader in Gaming Entertainment. Sto...
# Counter Logic Gaming   CLG is a premiere esports gaming organization ...
#
#                                      Channel ID              Date Created  \
# Team
