# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import time

# %%
#Read CSV files
Clean_data="clean_data.csv"
Merged_df=pd.read_csv(Clean_data,encoding="ISO-8859-1",sep=";")
Merged_df.head()
# Out:
#                    Team  Twitter_Compound_Score         Region  Wins  Losses  \
# 0           100 Thieves                0.172566  North America    13       6
# 1                Cloud9                0.138294  North America    12       8
# 2         Clutch Gaming                0.217552  North America    11       9
# 3  Counter Logic Gaming                0.311433  North America     7      11
# 4              Echo Fox                0.260797  North America    12       7
#
#    Win_Rate  Youtube_Compound_Score  Subscriber_Count  View_Count
# 0  0.684211                0.351237            323071    35207210
# 1  0.600000               -0.018238             88420     6987846
# 2  0.550000                0.249024             10902      532957
# 3  0.388889                0.127185             34748     1729011
# 4  0.631579                0.121082            177315    12217267

# %%
#Create bubble plot using seaborn and matplotlib libraries
sns.lmplot(x='Twitter_Compound_Score', y='Win_Rate', data=Merged_df,
           fit_reg=False,hue='Team'
           ,scatter_kws={ 
           "alpha":0.9,"linewidth":1,"edgecolors":'k'}) 

#Set title for the plot
ax = plt.gca()
ax.set_title("Compound Score vs Win Rate")
# Out:
# Text(0.5,1,'Compound Score vs Win Rate')

# %%
sns.set(style="whitegrid")

# Make an example dataset with y ~ x

x = Merged_df["Youtube_Compound_Score"]
y = Merged_df["Win_Rate"]

# Plot the residuals after fitting a linear model
sns.residplot(x, y, lowess=True,color="b", scatter_kws={ 
           "alpha":0.9,"linewidth":1,"edgecolors":'k'})

# %%
sns.regplot(x="Youtube_Compound_Score", y="Subscriber_Count", data=Merged_df,color="r")

plt.title("Youtube Compound Score vs Youtube Subscriber Count")
plt.xlabel("Youtube Compound Score")
plt.ylabel("Subscriber Count")

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("YoutubeComvsSub.png")
plt.show()
